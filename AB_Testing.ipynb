# %% [markdown]
# # A-B Testing
#
# ### Setup

# %%
from openai import OpenAI
import os
import base64
import requests

from collections import Counter

from IPython.display import display, Markdown, Image


from dotenv import load_dotenv
# Load API key
_ = load_dotenv()

# %%
def query_LLM(messages=None, prompt=None, model='gpt-4o'):

    if messages is None and prompt:
        messages = [{ "role": "user", "content": prompt }]
    elif messages is None:
        return None
        
    completion = client.chat.completions.create(
      model=model,
      messages=messages
    )
    
    response = completion.choices[0].message.content

    return response

# %%
client = OpenAI()

# %%
productA = open('vito_prodA.md').read()
productB = open('productB.md').read()

# %%
display(Markdown(productA))
# Out:
# <!-- Vito Product Page -->
#
# <h1 align="center" style="font-size:3em; color:#2E3A59; margin-bottom:0;">🐾 Vito</h1>
# <h3 align="center" style="color:#00A8A8; font-weight:400;">Connect. Monitor. Care.</h3>
#
# <p align="center">
#   <img src="vito_logo.jpg" width="150" alt="Vito Collar Icon">
# </p>
#
# ---
#
# ## 💡 Collar Features
#
# <div style="display:grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap:1em; margin-top:1em;">
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>❤️ Heart Rate Monitoring</strong><br>
#     Track your pet’s heart rate in real-time to ensure optimal health and early detection of issues.
#   </div>
#
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>🏃 Activity & Step Tracking</strong><br>
#     Record steps, runs, and playtime to monitor daily activity levels.
#   </div>
#
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>💤 Sleep Tracking</strong><br>
#     Understand your pet’s rest cycles to improve their comfort and recovery.
#   </div>
#
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>🌡️ Temperature Monitoring</strong><br>
#     Detect overheating or cold stress through continuous body temperature tracking.
#   </div>
#
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>📍 GPS Tracking</strong><br>
#     Always know where your pet is with accurate, real-time GPS location updates.
#   </div>
#
#   <div style="background:#F8FAFC; border-radius:12px; padding:1em; box-shadow:0 2px 6px rgba(0,0,0,0.05);">
#     <strong>💧 Waterproof Design</strong><br>
#     Adventure-proof — rain or shine, the Vito Collar is built to last.
#   </div>
# </div>
#
# ---
#
# ## 📱 Connect with Our App
#
# <p align="center">
#   <img src="https://img.icons8.com/color/452/smartphone.png" width="120" alt="App Icon">
# </p>
#
# <div style="display:flex; flex-wrap:wrap; gap:1em; justify-content:center;">
#   <div style="background:#E6FFFA; border-left:6px solid #00A8A8; padding:1em; border-radius:8px; width:280px;">
#     <strong>Real-time Vitals Dashboard</strong><br>
#     Monitor your pet’s health data at a glance.
#   </div>
#
#   <div style="background:#E6FFFA; border-left:6px solid #00A8A8; padding:1em; border-radius:8px; width:280px;">
#     <strong>Data & Trends Over Time</strong><br>
#     View patterns in sleep, exercise, and more.
#   </div>
#
#   <div style="background:#E6FFFA; border-left:6px solid #00A8A8; padding:1em; border-radius:8px; width:280px;">
#     <strong>Shareable Health Reports</strong><br>
#     Send wellness summaries to your vet or family.
#   </div>
#
#   <div style="background:#E6FFFA; border-left:6px solid #00A8A8; padding:1em; border-radius:8px; width:280px;">
#     <strong>Connect with Friends</strong><br>
#     Build a community of pet lovers and share milestones.
#   </div>
# </div>
#
# ---
#
# ## ⭐ Reviews and Endorsements
#
# > “Vito gave me peace of mind. I can finally keep track of Luna’s activity and health even when I’m at work.”
# > — <em>Sarah M., Dog Owner</em>
#
# > “As a vet, I love how Vito simplifies pet health monitoring. It’s data-driven care done right.”
# > — <em>Dr. Alex Rivera, DVM</em>
#
# ---
#
# <p align="center">
#   <a href="#" style="background:#00A8A8; color:white; padding:0.8em 2em; border-radius:50px; text-decoration:none; font-weight:bold;">Learn More</a>
# </p>
#
# <p align="center" style="color:#6B7280;">© 2025 Vito Technologies. All rights reserved.</p>

# %%
display(Markdown(productB))
# Out:
# # PetPulse
#
# <img src="https://github.com/carolinecummings19/comm4190_F25_Product_Task/blob/main/petpulse_logo.jpg" alt="Logo" width="50%">
#
# **PetPulse** - Your Dog's Health Guardian
#
# ---
#
# **Track Health, Wag More.**
#
# ---
#
# ## Product Overview
#
# Introducing PetPulse, a revolutionary smart collar that keeps you informed about your dog's health and wellbeing around the clock. Designed with advanced sensors, it tracks heart rate, activity level, sleep patterns, and more, providing you with real-time data via a user-friendly mobile app. PetPulse is crafted from durable, water-resistant materials and comes in various adjustable sizes and colors, ensuring a comfortable fit for any breed. Not only does it promote your peace of mind, but it also alerts you to potential health anomalies with precision, enabling early intervention. Whether it's for high-energy playtime or restful napping, know you're doing the best for your furry friend with PetPulse, the ultimate fusion of care and technology in pet health monitoring.
#
# ---
#
# ## Key Features
#
# ### Advanced Heart Rate Monitoring
# Continuously tracks your dog's heart rate and alerts you to any irregularities, allowing for early detection of potential health issues.
#
# ### Activity Level Tracking
# Monitors your dog's activity levels throughout the day, from vigorous play to restful relaxation, helping you ensure they're getting the right amount of exercise.
#
# ### Sleep Pattern Analysis
# Analyzes your dog's sleep patterns to provide insights into their rest quality, helping you ensure they have a healthy sleep schedule.
#
# ### Real-Time Health Alerts
# Sends real-time notifications to your mobile app if any health anomalies or significant changes in your dog's condition are detected, enabling prompt attention.
#
# ### Durable, Water-Resistant Design
# Crafted from robust, water-resistant materials to withstand various weather conditions, ensuring long-lasting use and comfort for your pet.
#
# ---
#
# ## Customer Reviews
#
# ### ⭐⭐⭐⭐⭐
# **"A Lifesaver for My Senior Dog"**
# *Sarah M., Golden Retriever Owner*
#
# "PetPulse detected an irregular heartbeat in my 10-year-old Buddy that I would have never noticed. Thanks to the early alert, my vet was able to diagnose and treat a heart condition early. This device literally saved his life!"
#
# ---
#
# ### ⭐⭐⭐⭐⭐
# **"Peace of Mind While I'm at Work"**
# *James T., Labrador Owner*
#
# "I used to worry about Max all day while I was at the office. Now with PetPulse, I can check his activity levels and get alerts if anything's wrong. It's like having a veterinary assistant watching over him 24/7."
#
# ---
#
# ### ⭐⭐⭐⭐⭐
# **"Perfect for Active Dogs"**
# *Emily R., Border Collie Owner*
#
# "Luna is incredibly active, and PetPulse helps me make sure she's getting enough rest between her adventures. The sleep tracking feature has been invaluable in establishing a healthy routine for her."
#
# ---
#
# ### ⭐⭐⭐⭐⭐
# **"Durable and Reliable"**
# *Michael C., German Shepherd Owner*
#
# "My dog loves water, and I was worried about finding a device that could keep up with him. PetPulse has survived countless swimming sessions, rain walks, and rough play. It's built to last!"
#
# ---
#
# ## Professional Endorsements
#
# ### Dr. Rebecca Martinez, DVM
# **Veterinary Cardiologist, Animal Heart Center**
#
# > "As a veterinary cardiologist, I've seen firsthand how early detection can make all the difference in treating canine heart conditions. PetPulse's continuous monitoring capabilities provide pet owners with a powerful tool for preventive care. I regularly recommend it to my clients, especially those with breeds predisposed to cardiac issues."
#
# ---
#
# ### Dr. Alan Cho, DVM, DACVIM
# **Board-Certified Veterinary Internal Medicine Specialist**
#
# > "The data provided by PetPulse has proven invaluable in my practice. The detailed activity and sleep patterns help me make more informed diagnoses and treatment plans. This technology represents a significant advancement in companion animal healthcare."
#
# ---
#
# ### Pet Health Magazine
# **Editor's Choice Award 2024**
#
# > "PetPulse stands out in the crowded pet tech market with its comprehensive health monitoring features and user-friendly interface. It's an essential tool for any pet owner who wants to take a proactive approach to their dog's health."
#
# ---
#
# ### American Kennel Club (AKC)
# **Technology Innovation Recognition**
#
# > "PetPulse exemplifies the future of responsible pet ownership. By combining cutting-edge technology with practical health monitoring, it empowers owners to provide better care for their canine companions."
#
# ---
#
# ## Why Choose PetPulse?
#
# ✓ **Veterinarian Recommended** - Trusted by animal health professionals
# ✓ **24/7 Monitoring** - Continuous health tracking without interruption
# ✓ **Easy to Use** - Simple setup and intuitive mobile app
# ✓ **Long Battery Life** - Up to 14 days on a single charge
# ✓ **Comfortable Fit** - Lightweight design that won't bother your pet
# ✓ **Secure Data** - Your pet's health information is encrypted and protected
#
# ---
#
# ## Get Started Today
#
# Give your dog the health monitoring they deserve. Join thousands of pet owners who trust PetPulse to keep their furry friends healthy and happy.
#
# **Track Health, Wag More.**

# %%
system_prompt = "You are consumer who is a dog owner"

rating_prompt = f'''
   Read the websites for each of these two products
   1. Vito
   2. PetPulse

   {productA}

   ----

   {productB}

   ----
   
   Pay careful attention to the features, descriptions and user reviews.

   Rate each product on scale of 0 (never buy) to 10 (buy immediately).
   Show just your ratings and which product you prefer.
   Then briefly explain your ratings
'''

# %%
consumers = [
    "dog owner, male, 50s",
    "dog owner, female, 30s",
    "no pet owner, male, 50s",
    "no pet owner, female, 30s",
    "cat owner, male, 40s",
    "cat owner, female, 70s",
]

# %%
for consumer in consumers:
    print(f"\n-----\n{consumer}")

    messages = [
       {"role": "system", "content": system_prompt.format(description=consumer)},
       {"role": "system", "content": rating_prompt}
    ]

    response = query_LLM(messages=messages)

    print(response,'\n')
# Out:
# -----
# dog owner, male, 50s
# Vito: 8/10
# PetPulse: 9/10
#
# Preferred Product: PetPulse
#
# **Explanation:**
#
# Both Vito and PetPulse offer a comprehensive range of features that can greatly benefit pet owners by providing key health insights about their dogs. However, PetPulse slightly edges out Vito due to the following reasons:
#
# 1. **Health Alerts:**
#    - PetPulse provides real-time health alerts which notify the owner of any anomalies or significant changes in the dog's condition. This proactive approach to health monitoring can be crucial for early intervention.
#
# 2. **Veterinary Endorsements and Professional Validation:**
#    - PetPulse is supported by endorsements from veterinarians and has received recognition from professional organizations such as the American Kennel Club and Pet Health Magazine. These endorsements offer strong validation for the product's effectiveness and reliability.
#
# 3. **User Reviews and Experiences:**
#    - The user reviews for PetPulse highlight its practical use in detecting health issues early, specifically mentioning a life-saving detection of an irregular heartbeat. This emphasizes the real-world value and impact of its features.
#
# 4. **Battery Life and Durability:**
#    - PetPulse offers a longer battery life (up to 14 days) which can be extremely convenient for pet owners. Additionally, it is emphasized for its durable design, which is a comforting guarantee for dogs that love various physical activities and outdoor adventures.
#
# Vito also provides an impressive suite of features, including GPS tracking and a community aspect through its app, which would be appealing for many pet owners. However, the detailed health alerts and professional endorsements give PetPulse an edge in providing peace of mind and the assurance of early health issue detection.
#
#
# -----
# dog owner, female, 30s
# Ratings:
#
# 1. Vito: 9/10
# 2. PetPulse: 9/10
#
# Preferred Product: Vito
#
# Explanation:
#
# Both Vito and PetPulse offer advanced features for monitoring a dog's health, including heart rate monitoring, activity and sleep tracking, and durable, water-resistant designs. Both products also emphasize real-time data through their mobile apps, allowing owners to keep track of their pet's well-being.
#
# However, Vito has a slight edge due to its additional features such as temperature monitoring and GPS tracking, which offer more comprehensive health management and peace of mind regarding a pet's location. Vito's capability to shareable health reports and community connection features are also attractive for someone keen on data sharing and pet-related social networking.
#
# PetPulse has some compelling endorsements from veterinary professionals and offers excellent reviews, especially regarding heart health monitoring. The recognition from professional organizations and long battery life are significant points in its favor.
#
# Overall, both products are excellent choices with their unique strengths, but Vito's extra features and social app elements slightly tilt the preference in its direction.
#
#
# -----
# no pet owner, male, 50s
# **Ratings:**
#
# - Vito: 8
# - PetPulse: 9
#
# **Preferred Product: PetPulse**
#
# **Explanation of Ratings:**
#
# 1. **Vito:**
#    - *Features*: Vito offers a comprehensive range of features like heart rate, activity & step tracking, sleep and temperature monitoring, and GPS tracking. Its waterproof design is a great bonus for active pets.
#    - *User Feedback*: Reviews are positive, highlighting peace of mind through comprehensive health monitoring.
#    - *App Connectivity*: The app provides useful insights and sharing capabilities but does not highlight real-time alerts as a standout feature.
#    - *Reason for Rating*: The absence of specific mention of real-time health alerts is a drawback since instant notifications could be crucial in dealing with health anomalies right away. This drops Vito's rating slightly.
#
# 2. **PetPulse:**
#    - *Features*: Covers heart rate, activity, and sleep pattern monitoring, similar to Vito, but emphasizes real-time health alerts and veterinary-endorsed capabilities.
#    - *User Feedback*: Highly positive with specific anecdotes about saving dogs' lives and strong endorsements from veterinary professionals.
#    - *App Connectivity*: Detailed emphasis on real-time alerts and data critical for preventive care, which positions it as slightly more proactive in health monitoring.
#    - *Design & Durability*: Highlighted as very resilient, especially for water-loving pets, enhancing its reliability.
#    - *Reason for Rating*: The real-time health alert feature and high praise from the veterinary community make it stand out as more proactive for pet health intervention, thus earning a higher rating. The extra endorsement and detailed user stories provide a more compelling use-case scenario.
#
# Overall, both products are strong contenders, but PetPulse's emphasis on real-time alerts and veterinary recommendations gives it an edge for proactive pet health management.
#
#
# -----
# no pet owner, female, 30s
# **Ratings:**
#
# - **Vito**: 8/10
# - **PetPulse**: 9/10
#
# **Preferred Product: PetPulse**
#
# **Explanation:**
#
# **Vito:**
# - **Pros:**
#   - Comprehensive health monitoring features including heart rate, activity, sleep, temperature, and GPS tracking.
#   - Waterproof and durable design ideal for pets that are active outdoors.
#   - Real-time data and trends available through an engaging mobile app, along with a social aspect for connecting with other pet owners.
#   - Positive reviews and endorsements that establish trust.
#
# - **Cons:**
#   - While comprehensive, it doesn’t explicitly include real-time health alerts that notify owners of potential anomalies, which is crucial for immediate intervention.
#
# **PetPulse:**
# - **Pros:**
#   - Offers real-time health alerts, which are critical for early intervention and peace of mind.
#   - High marks from veterinary professionals and an impressive range of endorsements, including an award and recognition from the AKC.
#   - Provides a secure, comprehensive health monitoring platform with a long battery life and a variety of comfortable fits.
#   - Customer reviews highlight life-saving experiences and satisfaction with its durability and reliability, especially for senior dogs and active breeds.
#
# - **Cons:**
#   - Does not specify GPS tracking capabilities which could be an important feature for some dog owners.
#
# PetPulse edges out slightly due to its emphasis on real-time alerts and strong professional endorsements, suggesting a robust and reliable service for proactive pet health management.
#
#
# -----
# cat owner, male, 40s
# ### Ratings:
#
# - **Vito:** 8/10
# - **PetPulse:** 9/10
#
# ### Preference: PetPulse
#
# ### Explanation:
#
# **Vito:**
# - **Strengths:**
#   - Comprehensive monitoring features including heart rate, activity, sleep, temperature, and GPS tracking.
#   - Strong focus on community engagement with app-based sharing and connectivity.
#   - Positive endorsements from pet owners and veterinarians.
#
# - **Considerations:**
#   - While it offers GPS tracking, which is a significant advantage, the review quotes are slightly less impactful in terms of specific life-saving instances or practical applications.
#   - Lacks specifics on battery life which is important for convenience and continuous use.
#
# **PetPulse:**
# - **Strengths:**
#   - Equally comprehensive health monitoring with advanced heart rate monitoring, and real-time alerts for health anomalies.
#   - Strong emphasis on early detection and intervention with real-life user testimonials highlighting critical health savings.
#   - Highly endorsed by veterinarians and recognized by reputable organizations like the American Kennel Club.
#   - Includes a detail on battery life, ensuring up to 14 days on a single charge, which adds to convenience.
#
# - **Considerations:**
#   - Focuses more on physical durability and continuous tracking, which might be more valuable for owners of active dogs or those with health conditions.
#
# Overall, both products are impressive, but PetPulse edges out slightly due to its emphasis on real-time alerts and the compelling testimonials of life-saving incidents, along with longer battery life clarity. These features are crucial for a pet owner who values immediate health insights and the practicality of a reliable, low-maintenance device.
#
#
# -----
# cat owner, female, 70s
# **Ratings:**
#
# - **Vito**: 8
# - **PetPulse**: 9
#
# **Preferred Product:** PetPulse
#
# **Explanation:**
#
# Both Vito and PetPulse offer impressive features for pet health monitoring, but PetPulse slightly edges out because of a few factors:
#
# 1. **Health Monitoring Features**: Both products include heart rate monitoring, activity, and sleep tracking. However, PetPulse offers real-time health alerts, which is a crucial feature for immediate attention to potential health anomalies.
#
# 2. **Durability and Design**: Both collars boast a durable, water-resistant design, essential for active dogs. PetPulse's customer reviews specifically highlight its reliability in varying conditions, which adds confidence in its durability for an active lifestyle.
#
# 3. **Customer and Professional Endorsements**: PetPulse has numerous positive customer reviews and strong professional endorsements, particularly in the field of cardiology, which suggests trust and reliability in detecting heart conditions. The endorsements from recognized bodies like the AKC and the Editor's Choice Award also enhance its credibility.
#
# 4. **Ease of Use and Battery Life**: The mention of a long battery life of up to 14 days and the user-friendly mobile app for PetPulse are significant advantages for convenience over extended periods without the need for frequent recharging.
#
# 5. **Additional Features**: While Vito offers benefits like community connection through its app and shareable health reports, the critical health-related features in PetPulse, such as real-time alerts and extensive professional commendations, align more closely with a high standard of proactive pet care.
#
# Overall, while Vito has strong offerings, PetPulse's additional critical safety features and strong professional backing make it slightly more appealing for ensuring optimal care and quick response to potential health issues in dogs.
